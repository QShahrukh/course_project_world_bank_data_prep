# %%
import pandas as pd

# %%
women_data = pd.read_csv('API_SE.PRM.CMPT.FE.ZS_DS2_en_csv_v2_5359531.csv', skiprows=3)

# %%
women_data.head(3)
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Primary completion rate, female (% of relevant...  SE.PRM.CMPT.FE.ZS   NaN
# 1  Primary completion rate, female (% of relevant...  SE.PRM.CMPT.FE.ZS   NaN
# 2  Primary completion rate, female (% of relevant...  SE.PRM.CMPT.FE.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...        2013       2014       2015  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  101.255234  101.55587        NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...   66.028069   66.26329  66.115013
# 2   NaN   NaN   NaN   NaN   NaN  ...         NaN        NaN        NaN
#
#         2016       2017       2018       2019       2020  2021  Unnamed: 66
# 0        NaN        NaN        NaN        NaN        NaN   NaN          NaN
# 1  66.932449  68.167793  69.499100  69.990547  70.825378   NaN          NaN
# 2  63.604069  66.688881  67.129303  65.761513        NaN   NaN          NaN
#
# [3 rows x 67 columns]

# %%
women_data = women_data.drop(['Indicator Name', 'Indicator Code', 'Unnamed: 66'], axis=1)

# %%
women_data = women_data.melt(id_vars=['Country Name', 'Country Code'])
women_data.columns = ['Country Name', 'Country Code', 'year', 'percentage']

# %%
women_data
# Out:
#                       Country Name Country Code  year  percentage
# 0                            Aruba          ABW  1960         NaN
# 1      Africa Eastern and Southern          AFE  1960         NaN
# 2                      Afghanistan          AFG  1960         NaN
# 3       Africa Western and Central          AFW  1960         NaN
# 4                           Angola          AGO  1960         NaN
# ...                            ...          ...   ...         ...
# 16487                       Kosovo          XKX  2021         NaN
# 16488                  Yemen, Rep.          YEM  2021         NaN
# 16489                 South Africa          ZAF  2021         NaN
# 16490                       Zambia          ZMB  2021         NaN
# 16491                     Zimbabwe          ZWE  2021   86.107933
#
# [16492 rows x 4 columns]

# %%
len(women_data)
# Out:
# 16492

# %%
women_data_metadata = pd.read_csv('Metadata_Country_API_SE.PRM.CMPT.FE.ZS_DS2_en_csv_v2_5359531.csv')

# %%
women_data_metadata
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa           Low income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# 2    The reporting period for national accounts dat...
# 3    22 countries, stretching from the westernmost ...
# 4    The World Bank systematically assesses the app...
# ..                                                 ...
# 260                                                NaN
# 261  The World Bank systematically assesses the app...
# 262  Fiscal year end: March 31; reporting period fo...
# 263  National accounts data were rebased to reflect...
# 264  National Accounts data are reported in Zimbabw...
#
#                        TableName  Unnamed: 5
# 0                          Aruba         NaN
# 1    Africa Eastern and Southern         NaN
# 2                    Afghanistan         NaN
# 3     Africa Western and Central         NaN
# 4                         Angola         NaN
# ..                           ...         ...
# 260                       Kosovo         NaN
# 261                  Yemen, Rep.         NaN
# 262                 South Africa         NaN
# 263                       Zambia         NaN
# 264                     Zimbabwe         NaN
#
# [265 rows x 6 columns]

# %%
women_data = women_data.merge(women_data_metadata, on=['Country Code'], how='left')

# %%
women_data
# Out:
#                       Country Name Country Code  year  percentage  \
# 0                            Aruba          ABW  1960         NaN
# 1      Africa Eastern and Southern          AFE  1960         NaN
# 2                      Afghanistan          AFG  1960         NaN
# 3       Africa Western and Central          AFW  1960         NaN
# 4                           Angola          AGO  1960         NaN
# ...                            ...          ...   ...         ...
# 16487                       Kosovo          XKX  2021         NaN
# 16488                  Yemen, Rep.          YEM  2021         NaN
# 16489                 South Africa          ZAF  2021         NaN
# 16490                       Zambia          ZMB  2021         NaN
# 16491                     Zimbabwe          ZWE  2021   86.107933
#
#                            Region          IncomeGroup  \
# 0       Latin America & Caribbean          High income
# 1                             NaN                  NaN
# 2                      South Asia           Low income
# 3                             NaN                  NaN
# 4              Sub-Saharan Africa  Lower middle income
# ...                           ...                  ...
# 16487       Europe & Central Asia  Upper middle income
# 16488  Middle East & North Africa           Low income
# 16489          Sub-Saharan Africa  Upper middle income
# 16490          Sub-Saharan Africa           Low income
# 16491          Sub-Saharan Africa  Lower middle income
#
#                                             SpecialNotes  \
# 0                                                    NaN
# 1      26 countries, stretching from the Red Sea in t...
# 2      The reporting period for national accounts dat...
# 3      22 countries, stretching from the westernmost ...
# 4      The World Bank systematically assesses the app...
# ...                                                  ...
# 16487                                                NaN
# 16488  The World Bank systematically assesses the app...
# 16489  Fiscal year end: March 31; reporting period fo...
# 16490  National accounts data were rebased to reflect...
# 16491  National Accounts data are reported in Zimbabw...
#
#                          TableName  Unnamed: 5
# 0                            Aruba         NaN
# 1      Africa Eastern and Southern         NaN
# 2                      Afghanistan         NaN
# 3       Africa Western and Central         NaN
# 4                           Angola         NaN
# ...                            ...         ...
# 16487                       Kosovo         NaN
# 16488                  Yemen, Rep.         NaN
# 16489                 South Africa         NaN
# 16490                       Zambia         NaN
# 16491                     Zimbabwe         NaN
#
# [16492 rows x 9 columns]

# %%
# Drop rows where percentage is missing for country.

# %%
women_data = women_data.dropna(subset=['percentage'])

# %%
women_data['IncomeGroup'] = women_data['IncomeGroup'].fillna('OTHER')
# Out:
# /var/folders/c3/czblc2fd5djb8h632pgk8z4h0000gn/T/ipykernel_33325/3685429692.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   women_data['IncomeGroup'] = women_data['IncomeGroup'].fillna('OTHER')

# %%
women_data['Region'] = women_data['Region'].fillna('OTHER')
# Out:
# /var/folders/c3/czblc2fd5djb8h632pgk8z4h0000gn/T/ipykernel_33325/2813440840.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   women_data['Region'] = women_data['Region'].fillna('OTHER')

# %%
# Save women Primary completion rate date. 
women_data.to_csv('women_clean_data.csv')

# %%
# Preparing child mortality data.

# %%
child_data = pd.read_csv('API_SH.DYN.MORT_DS2_en_csv_v2_5358988.csv', skiprows=3)

# %%
child_data = child_data.drop(['Indicator Name', 'Indicator Code', 'Unnamed: 66'], axis=1)

# %%
child_data = child_data.melt(id_vars=['Country Name', 'Country Code'])
child_data.columns = ['Country Name', 'Country Code', 'year', 'percentage']
child_data
# Out:
#                       Country Name Country Code  year  percentage
# 0                            Aruba          ABW  1960         NaN
# 1      Africa Eastern and Southern          AFE  1960         NaN
# 2                      Afghanistan          AFG  1960       357.3
# 3       Africa Western and Central          AFW  1960         NaN
# 4                           Angola          AGO  1960         NaN
# ...                            ...          ...   ...         ...
# 16487                       Kosovo          XKX  2021        10.0
# 16488                  Yemen, Rep.          YEM  2021        61.9
# 16489                 South Africa          ZAF  2021        32.8
# 16490                       Zambia          ZMB  2021        57.7
# 16491                     Zimbabwe          ZWE  2021        49.5
#
# [16492 rows x 4 columns]

# %%
child_data_metadata = pd.read_csv('Metadata_Country_API_SH.DYN.MORT_DS2_en_csv_v2_5358988.csv')

# %%
child_data_metadata
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa           Low income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# 2    The reporting period for national accounts dat...
# 3    22 countries, stretching from the westernmost ...
# 4    The World Bank systematically assesses the app...
# ..                                                 ...
# 260                                                NaN
# 261  The World Bank systematically assesses the app...
# 262  Fiscal year end: March 31; reporting period fo...
# 263  National accounts data were rebased to reflect...
# 264  National Accounts data are reported in Zimbabw...
#
#                        TableName  Unnamed: 5
# 0                          Aruba         NaN
# 1    Africa Eastern and Southern         NaN
# 2                    Afghanistan         NaN
# 3     Africa Western and Central         NaN
# 4                         Angola         NaN
# ..                           ...         ...
# 260                       Kosovo         NaN
# 261                  Yemen, Rep.         NaN
# 262                 South Africa         NaN
# 263                       Zambia         NaN
# 264                     Zimbabwe         NaN
#
# [265 rows x 6 columns]

# %%
child_data = child_data.merge(child_data_metadata, on=['Country Code'], how='left')

# %%
child_data
# Out:
#                       Country Name Country Code  year  percentage  \
# 0                            Aruba          ABW  1960         NaN
# 1      Africa Eastern and Southern          AFE  1960         NaN
# 2                      Afghanistan          AFG  1960       357.3
# 3       Africa Western and Central          AFW  1960         NaN
# 4                           Angola          AGO  1960         NaN
# ...                            ...          ...   ...         ...
# 16487                       Kosovo          XKX  2021        10.0
# 16488                  Yemen, Rep.          YEM  2021        61.9
# 16489                 South Africa          ZAF  2021        32.8
# 16490                       Zambia          ZMB  2021        57.7
# 16491                     Zimbabwe          ZWE  2021        49.5
#
#                            Region          IncomeGroup  \
# 0       Latin America & Caribbean          High income
# 1                             NaN                  NaN
# 2                      South Asia           Low income
# 3                             NaN                  NaN
# 4              Sub-Saharan Africa  Lower middle income
# ...                           ...                  ...
# 16487       Europe & Central Asia  Upper middle income
# 16488  Middle East & North Africa           Low income
# 16489          Sub-Saharan Africa  Upper middle income
# 16490          Sub-Saharan Africa           Low income
# 16491          Sub-Saharan Africa  Lower middle income
#
#                                             SpecialNotes  \
# 0                                                    NaN
# 1      26 countries, stretching from the Red Sea in t...
# 2      The reporting period for national accounts dat...
# 3      22 countries, stretching from the westernmost ...
# 4      The World Bank systematically assesses the app...
# ...                                                  ...
# 16487                                                NaN
# 16488  The World Bank systematically assesses the app...
# 16489  Fiscal year end: March 31; reporting period fo...
# 16490  National accounts data were rebased to reflect...
# 16491  National Accounts data are reported in Zimbabw...
#
#                          TableName  Unnamed: 5
# 0                            Aruba         NaN
# 1      Africa Eastern and Southern         NaN
# 2                      Afghanistan         NaN
# 3       Africa Western and Central         NaN
# 4                           Angola         NaN
# ...                            ...         ...
# 16487                       Kosovo         NaN
# 16488                  Yemen, Rep.         NaN
# 16489                 South Africa         NaN
# 16490                       Zambia         NaN
# 16491                     Zimbabwe         NaN
#
# [16492 rows x 9 columns]

# %%
child_data = child_data.dropna(subset=['percentage'])

# %%
child_data
# Out:
#                Country Name Country Code  year  percentage  \
# 2               Afghanistan          AFG  1960       357.3
# 8      United Arab Emirates          ARE  1960       201.6
# 12      Antigua and Barbuda          ATG  1960        86.3
# 13                Australia          AUS  1960        24.8
# 14                  Austria          AUT  1960        42.9
# ...                     ...          ...   ...         ...
# 16487                Kosovo          XKX  2021        10.0
# 16488           Yemen, Rep.          YEM  2021        61.9
# 16489          South Africa          ZAF  2021        32.8
# 16490                Zambia          ZMB  2021        57.7
# 16491              Zimbabwe          ZWE  2021        49.5
#
#                            Region          IncomeGroup  \
# 2                      South Asia           Low income
# 8      Middle East & North Africa          High income
# 12      Latin America & Caribbean          High income
# 13            East Asia & Pacific          High income
# 14          Europe & Central Asia          High income
# ...                           ...                  ...
# 16487       Europe & Central Asia  Upper middle income
# 16488  Middle East & North Africa           Low income
# 16489          Sub-Saharan Africa  Upper middle income
# 16490          Sub-Saharan Africa           Low income
# 16491          Sub-Saharan Africa  Lower middle income
#
#                                             SpecialNotes  \
# 2      The reporting period for national accounts dat...
# 8                                                    NaN
# 12                                                   NaN
# 13     The reporting period for national accounts dat...
# 14     A simple multiplier is used to convert the nat...
# ...                                                  ...
# 16487                                                NaN
# 16488  The World Bank systematically assesses the app...
# 16489  Fiscal year end: March 31; reporting period fo...
# 16490  National accounts data were rebased to reflect...
# 16491  National Accounts data are reported in Zimbabw...
#
#                   TableName  Unnamed: 5
# 2               Afghanistan         NaN
# 8      United Arab Emirates         NaN
# 12      Antigua and Barbuda         NaN
# 13                Australia         NaN
# 14                  Austria         NaN
# ...                     ...         ...
# 16487                Kosovo         NaN
# 16488           Yemen, Rep.         NaN
# 16489          South Africa         NaN
# 16490                Zambia         NaN
# 16491              Zimbabwe         NaN
#
# [12665 rows x 9 columns]

# %%
child_data['IncomeGroup'] = child_data['IncomeGroup'].fillna('OTHER')
child_data['Region'] = child_data['Region'].fillna('OTHER')
# Out:
# /var/folders/c3/czblc2fd5djb8h632pgk8z4h0000gn/T/ipykernel_33325/2229559405.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   child_data['IncomeGroup'] = child_data['IncomeGroup'].fillna('OTHER')
# /var/folders/c3/czblc2fd5djb8h632pgk8z4h0000gn/T/ipykernel_33325/2229559405.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   child_data['Region'] = child_data['Region'].fillna('OTHER')

# %%
child_data
# Out:
#                Country Name Country Code  year  percentage  \
# 2               Afghanistan          AFG  1960       357.3
# 8      United Arab Emirates          ARE  1960       201.6
# 12      Antigua and Barbuda          ATG  1960        86.3
# 13                Australia          AUS  1960        24.8
# 14                  Austria          AUT  1960        42.9
# ...                     ...          ...   ...         ...
# 16487                Kosovo          XKX  2021        10.0
# 16488           Yemen, Rep.          YEM  2021        61.9
# 16489          South Africa          ZAF  2021        32.8
# 16490                Zambia          ZMB  2021        57.7
# 16491              Zimbabwe          ZWE  2021        49.5
#
#                            Region          IncomeGroup  \
# 2                      South Asia           Low income
# 8      Middle East & North Africa          High income
# 12      Latin America & Caribbean          High income
# 13            East Asia & Pacific          High income
# 14          Europe & Central Asia          High income
# ...                           ...                  ...
# 16487       Europe & Central Asia  Upper middle income
# 16488  Middle East & North Africa           Low income
# 16489          Sub-Saharan Africa  Upper middle income
# 16490          Sub-Saharan Africa           Low income
# 16491          Sub-Saharan Africa  Lower middle income
#
#                                             SpecialNotes  \
# 2      The reporting period for national accounts dat...
# 8                                                    NaN
# 12                                                   NaN
# 13     The reporting period for national accounts dat...
# 14     A simple multiplier is used to convert the nat...
# ...                                                  ...
# 16487                                                NaN
# 16488  The World Bank systematically assesses the app...
# 16489  Fiscal year end: March 31; reporting period fo...
# 16490  National accounts data were rebased to reflect...
# 16491  National Accounts data are reported in Zimbabw...
#
#                   TableName  Unnamed: 5
# 2               Afghanistan         NaN
# 8      United Arab Emirates         NaN
# 12      Antigua and Barbuda         NaN
# 13                Australia         NaN
# 14                  Austria         NaN
# ...                     ...         ...
# 16487                Kosovo         NaN
# 16488           Yemen, Rep.         NaN
# 16489          South Africa         NaN
# 16490                Zambia         NaN
# 16491              Zimbabwe         NaN
#
# [12665 rows x 9 columns]

# %%
child_data.to_csv('child_clean_data.csv')
